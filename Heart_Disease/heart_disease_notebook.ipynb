# %% [markdown]
# # Heart Disease Classification Project Environment

# %% [markdown]
# ## This Project is about classifying whether or not a patient has heart disease

# %% [markdown]
# ![title](ml-framework.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# The following table shows heart disease information for patients.

# %% [markdown]
# ## 1. Problem Definition
#
# Predict heart disease

# %% [markdown]
# ## 2. Data

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head(20)

# %%
df.target.value_counts().plot(kind="bar")
