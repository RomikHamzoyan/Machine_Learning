# %%
# Import NumPy as its abbreviation 'np'

import numpy as np

# %%
# Create a 1-dimensional NumPy array using np.array()
arr1 = np.array([1,2,3])

# Create a 2-dimensional NumPy array using np.array()
arr2 = np.array([[1,2,3],[4,5,6]])

# Create a 3-dimensional Numpy array using np.array()
arr3 = np.array([
    [
        [1,2,3],[4,5,6]
    ],
    [
        [11,22,33],[44,55,66]
    ]
])

# %%
# Attributes of 1,2,3-dimensional array (shape, 
# number of dimensions, data type, size and type)

arr1.ndim,arr1.shape, type(arr1), arr1.size

# %%
arr2.ndim,arr2.shape, type(arr2), arr2.size

# %%
arr3.ndim,arr3.shape, type(arr3), arr3.size

# %%
# Import pandas and create a DataFrame out of one
# of the arrays you've created
import pandas as pd

# %%
df = pd.DataFrame(arr1, index=["00","11","22"], columns=["00"])
df

# %%
# Create an array of shape (10, 2) with only ones

ones = np.ones(shape = [10,2])
ones

# %%
# Create an array of shape (7, 2, 3) of only zeros

zeros = np.zeros(shape=[7,2,3])

# %%
zeros

# %%
# Create an array within a range of 0 and 100 with step 3
range_array = np.arange(0,100,3)
range_array

# %%
# Create a random array with numbers between 0 and 10 of size (7, 2)
random_array = np.random.randint(10, size=(7,2))
random_array

# %%
# Create a random array of floats between 0 & 1 of shape (3, 5)
random_array = np.random.random(size = (3,5))
random_array

# %%
# Set the random seed to 42
np.random.seed(42)
# Create a random array of numbers between 0 & 10 of size (4, 6)
rand_array = np.random.randint(10, size=(4,6))
rand_array

# %%
# Create an array of random numbers between 1 & 10 of size (3, 7)
# and save it to a variable

rand_array = np.random.randint(1,10,size = (3,7))

# Find the unique numbers in the array you just created

rand_array

# %%
np.unique(rand_array)

# %%
# Find the 0'th index of the latest array you created
rand_array[0]
# Get the first 2 rows of latest array you created
rand_array[:2]

# %%
# Get the first 2 values of the first 2 rows of the latest array

rand_array[:1,:2]

# %%
# Create a random array of numbers between 0 & 10 and an array of ones
# both of size (3, 5), save them both to variables
rand_array = np.random.randint(0,10,size = (3,5))
ones = np.ones(shape = (3,5))

# %%
ones+rand_array 

# Add the two arrays together

# %%
# Create another array of ones of shape (5, 3)
ones = np.ones(shape = (5,3))

# %%
# Try add the array of ones and the other most recent array together
ones+rand_array

# %%
#fix Transpose
ones.T + rand_array

# %%
# Create another array of ones of shape (3, 5)
ones = np.ones(shape = (3,5))

# %%
# Subtract the new array of ones from the other most recent array
ones - rand_array
# Multiply the ones array with the latest array
ones * rand_array
# Take the latest array to the power of 2 using '**'
rand_array ** 2

# %%
# Do the same thing with np.square()

np.square(rand_array)

# %%
# Find the mean of the latest array using np.mean()

np.mean(rand_array)

# %%
# Find the maximum of the latest array using np.max()
np.max(rand_array)
# Find the minimum of the latest array using np.min()
np.min(rand_array)

# %%
# Find the standard deviation of the latest array

np.std(rand_array)

# %%
# Find the variance of the latest array

np.var(rand_array)

# %%
# Reshape the latest array to (3, 5, 1)
rand_array.reshape((3,5,1))

# %%
rand_array.T 

# Transpose the latest array

# %%
# Create two arrays of random integers between 0 to 10
# one of size (3, 3) the other of size (3, 2)
rand_array = np.random.randint(0,10,size = (3,3))
rand2_array = np.random.randint(0,10,size = (3,2))

# %%
rand_array.dot(rand2_array) 

# Perform a dot product on the two newest arrays you created

# %%
# Create two arrays of random integers between 0 to 10
# both of size (4, 3)
rand_array = np.random.randint(0,10,size = (4,3))
rand2_array = np.random.randint(0,10,size = (4,3))

rand_array.dot(rand2_array.T)

# %%
# Create two arrays of random integers between 0 & 10 of the same shape
# and save them to variables
rand_array = np.random.randint(0,10,size = (3,3))
rand2_array = np.random.randint(0,10,size = (3,3))

# %%
rand_array>rand2_array # Compare the two arrays with '>'

# %%
rand_array>=rand2_array # Compare the two arrays with '>='

# %%
rand_array > 7 

# Find which elements of the first array are greater than 7

# %%
rand_array

# %%
rand_array == rand2_array 

# Which parts of each array are equal? (try using '==')

# %%
np.sort(rand_array) 

# Sort one of the arrays you just created in ascending order

# %%
np.argsort(rand_array) 

# Sort the indexes of one of the arrays you just created

# %%
# Find the index with the maximum value in one of the arrays you've created

np.argmax(rand_array, axis = 1)

# %%
 np.argmin(rand_array, axis = 1) 

# Find the index with the minimum value in one of the arrays you've created

# %%
 

# Find the indexes with the minimum values across the 0th axis (axis=0)
# of one of the arrays you created

np.argmin(rand_array, axis = 0)

# %%
# Create an array of normally distributed random numbers

rand_array = np.random.randn(5)
rand_array

# %%
# Create an array with 10 evenly spaced numbers between 1 and 100

rand_array = np.arange(1,100)
rand_array
