# %%
import pandas as pd

# %%
# ML Data Manipulation

# %% [markdown]
# # 2 main Datatypes

# %%
# series

# %%
series = pd.Series(["BMW","Toyota", "Honda"])

# %%
series

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["RED","BLUE","WHITE"])
colours

# %%
# DataFrame = 2-dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Colour":colours})
car_data

# %%
# Import data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales

# %%
# Anatomy of a DataFrame

# %% [markdown]
# ![](pandas-anatomy-of-a-dataframe.png)

# %%
# Exporting a DataFrame

# %%
# Setting `index=False` prevents pandas from writing the DataFrame index as an additional column in the CSV file.

# %%
car_sales.to_csv("exported-car-sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales

# %% [markdown]
# ## Describe Data

# %%
# Attribute
#get the datatypes of the columns
car_sales.dtypes

# Function 
# car_sales.to_csv()

# %%
car_sales.columns

# %%
car_columns = car_sales.columns

# %%
car_columns

# %%
car_sales.index

# %%
car_sales

# %%
car_sales.describe() # getting a general overview of the numeric columns

# %%
car_sales.info() # getting general informations abozt the columns

# %%
car_sales.mean(numeric_only = True) #parameter is necessary

# %%
car_prices = pd.Series([200,1700,1222,])

# %%
car_prices.mean()

# %%
car_sales.sum() # get the sum of each column

# %%
car_sales["Doors"].sum() #Access a specific column

# %%
len(car_sales) # get the count of rows

# %%
car_sales

# %% [markdown]
# ## View and selectin data

# %%
car_sales.head() #top 5 rows quick snapshot

# %%
car_sales.head(7)

# %%
car_sales.tail() # bottom 5 rows

# %%
# .loc & .iloc

# %%
animals = pd.Series(["cat","dog","bird", "panda","snake"], index = [0,3,9,8,3])

# %%
animals

# %%
animals.loc[3] # getting the index numbers

# %%
car_sales.loc[9]

# %%
#iloc refers to position the third element

# %%
animals.iloc[3]

# %%
car_sales.iloc[2]

# %%
animals.iloc[:3] # gives us the elements up to position 3

# %%
car_sales.loc[:3]

# %%
car_sales["Make"]

# %%
car_sales.Make # works only when in the name is no space

# %%
car_sales[car_sales["Make"] == "Toyota"] # Filtering Data

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"]) # Cross Tab columns

# %%
#Group by

# %%
car_sales.groupby(["Make"]).mean(numeric_only = True)

# %%
car_sales.groupby(["Colour"])

# %%
# Visualization

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype

# %%
# How to change the datatype of a column

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]","",regex = True).astype(int)

# %%
## ignore the cents!

# %%
car_sales["Price"] = car_sales["Price"].astype(str).str[:-2].astype(int)

# %%
car_sales["Price"]

# %%
car_sales["Price"].plot()

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower() # access the str value of a column with the property str

# %%
car_sales["Make"] = car_sales["Make"].str.lower() # assign new value the column

# %%
car_sales

# %%
#Working with missing Data NaN

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True)) # fill NAN values

# %%
car_sales_missing

# %%
car_sales_missing = car_sales_missing.dropna() #Drop all NAN Rows

# %%
car_sales_missing

# %%
car_sales_missing.to_csv("car_sales_missing_dropped")

# %%
#Column from series
seats_column = pd.Series([5,5,5,5,5])

# New Column calles seats 
car_sales["Seats"] = seats_column
car_sales

# %%
car_sales["Seats"]=car_sales["Seats"].fillna(5)

# %%
car_sales

# %%
#Column from Python List 
fuel_economy = [7.5,9.5,5.6,7.8,9.8,8.8,7.5,5.5,8.7,6] #the amount of the values must match the amount of the rows!
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"] # generate a new column with a calculation
car_sales

# %%
# create a column from a single value 
car_sales["Number of Wheels"] = 4
car_sales

# %%
car_sales["Passed the road safety"] = True
car_sales

# %%
car_sales.info()

# %%
# Remove a column

# %%
car_sales = car_sales.drop("Total fuel used", axis = 1) # axis 1 because of the anatomy

# %%
car_sales

# %%
car_sales=car_sales.sample(frac=1) # mix the order of the columns, frac is the fraction 1 = all 0.5 the half

# %%
car_sales

# %%
# Only select 20% of the data
car_sales.sample(frac = 0.2)

# %%
car_sales=car_sales.reset_index(drop = True) # Order by index

# %%
car_sales

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6) # Change km to Miles

# %%
car_sales

# %%
car_sales = car_sales.rename(columns={"Odometer (KM)":"Odometer (Miles)"}) # Change the name of a column

# %%
car_sales
